# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('sample_101_Mlbb_Heroes.csv')

# %%
df
# Out:
#         Name               Title  \
# 0      Aamon      Duke of Shards
# 1       Akai       Panda Warrior
# 2     Aldous     Soul Contractor
# 3      Alice      Queen of Blood
# 4      Alpha     Blade of Enmity
# ..       ...                 ...
# 95      Ruby     Little Red Hood
# 96    Selena       Abyssal Witch
# 97  Silvanna  Imperial Knightess
# 98   Terizla         Executioner
# 99    Thamuz           Lord Lava
#
#                                            Voice_Line Release_Date  \
# 0   It is better to be feared than loved, if you c...   2021-10-25
# 1                          Now Akai enters the scene!         2016
# 2                                        Primary Role         2018
# 3                                    Watch your back!         2016
# 4                              Test! Alpha is online.         2017
# ..                                                ...          ...
# 95                                     Secondary Role         2017
# ...

# %%
df.isna().sum()
# Out:
# Name               0
# Title              0
# Voice_Line         0
# Release_Date       0
# Primary_Role       0
# Secondary_Role    72
# Lane               0
# Hp                 0
# Hp_Regen           0
# Mana               0
# Mana_Regen         0
# Phy_Damage         0
# Mag_Damage         0
# Phy_Defence        0
# Mag_Defence        0
# Mov_Speed          0
# Esport_Wins        0
# Esport_Loss        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#df = df.drop('Title',axis=1)

# %%
#df = df.drop('Voice_Line',axis=1)

# %%
#df = df.drop('Release_Date',axis=1)

# %%
df
# Out:
#         Name Primary_Role Secondary_Role      Lane    Hp  Hp_Regen  Mana  \
# 0      Aamon     Assassin            NaN   Jungler  2614       8.0   455
# 1       Akai         Tank        Support    Roamer  2769       8.4   422
# 2     Aldous      Fighter            NaN  EXP Lane  2718       9.8   405
# 3      Alice         Mage           Tank  EXP Lane  2573       7.2   493
# 4      Alpha      Fighter            NaN  EXP Lane  2646       7.8   453
# ..       ...          ...            ...       ...   ...       ...   ...
# 95      Ruby      Fighter           Tank  EXP Lane  2646       7.8   453
# 96    Selena     Assassin           Mage   Jungler  2401       6.8   490
# 97  Silvanna      Fighter            NaN  EXP Lane  2868       7.8   430
# 98   Terizla      Fighter            NaN  EXP Lane  2728      10.8   430
# 99    Thamuz      Fighter            NaN  EXP Lane  2758       7.4     0
#
#     Mana_Regen  Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  \
# ...
