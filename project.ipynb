# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hero = pd.read_csv('sample_101_Mlbb_Heroes.csv')

hero.head()
# Out:
#      Name            Title                                         Voice_Line  \
# 0   Aamon   Duke of Shards  It is better to be feared than loved, if you c...
# 1    Akai    Panda Warrior                         Now Akai enters the scene!
# 2  Aldous  Soul Contractor                                       Primary Role
# 3   Alice   Queen of Blood                                   Watch your back!
# 4   Alpha  Blade of Enmity                             Test! Alpha is online.
#
#   Release_Date Primary_Role Secondary_Role      Lane    Hp  Hp_Regen  Mana  \
# 0   2021-10-25     Assassin            NaN   Jungler  2614       8.0   455
# 1         2016         Tank        Support    Roamer  2769       8.4   422
# 2         2018      Fighter            NaN  EXP Lane  2718       9.8   405
# 3         2016         Mage           Tank  EXP Lane  2573       7.2   493
# 4         2017      Fighter            NaN  EXP Lane  2646       7.8   453
#
# ...

# %%
hero.info()
hero.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            100 non-null    object
#  1   Title           100 non-null    object
#  2   Voice_Line      100 non-null    object
#  3   Release_Date    100 non-null    object
#  4   Primary_Role    100 non-null    object
#  5   Secondary_Role  28 non-null     object
#  6   Lane            100 non-null    object
#  7   Hp              100 non-null    int64
#  8   Hp_Regen        100 non-null    float64
#  9   Mana            100 non-null    int64
#  10  Mana_Regen      100 non-null    int64
#  11  Phy_Damage      100 non-null    int64
#  12  Mag_Damage      100 non-null    int64
#  13  Phy_Defence     100 non-null    int64
#  14  Mag_Defence     100 non-null    int64
#  15  Mov_Speed       100 non-null    int64
#  16  Esport_Wins     100 non-null    int64
# ...

# %%
hero = hero.drop(
    columns=["Secondary_Role", "Title", "Voice_Line", "Release_Date"],
    errors="ignore"
)

# %%
hero.head()
# Out:
#      Name Primary_Role      Lane    Hp  Hp_Regen  Mana  Mana_Regen  \
# 0   Aamon     Assassin   Jungler  2614       8.0   455          21
# 1    Akai         Tank    Roamer  2769       8.4   422          12
# 2  Aldous      Fighter  EXP Lane  2718       9.8   405          18
# 3   Alice         Mage  EXP Lane  2573       7.2   493          18
# 4   Alpha      Fighter  EXP Lane  2646       7.8   453          31
#
#    Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  \
# 0         115           0           19           15        250           43
# 1         115           0           24           15        260          540
# 2         129           0           21           15        260           95
# 3         114           0           21           15        240          364
# 4         121           0           25           15        260           24
#
#    Esport_Loss
# 0           42
# 1          524
# 2           92
# 3          352
# 4           33

# %%
hero.isnull().sum()
# Out:
# Name            0
# Primary_Role    0
# Lane            0
# Hp              0
# Hp_Regen        0
# Mana            0
# Mana_Regen      0
# Phy_Damage      0
# Mag_Damage      0
# Phy_Defence     0
# Mag_Defence     0
# Mov_Speed       0
# Esport_Wins     0
# Esport_Loss     0
# dtype: int64

# %%
hero.dtypes
# Out:
# Name             object
# Primary_Role     object
# Lane             object
# Hp                int64
# Hp_Regen        float64
# Mana              int64
# Mana_Regen        int64
# Phy_Damage        int64
# Mag_Damage        int64
# Phy_Defence       int64
# Mag_Defence       int64
# Mov_Speed         int64
# Esport_Wins       int64
# Esport_Loss       int64
# dtype: object

# %%
hero['Total_damage'] = hero['Phy_Damage'] + hero['Mag_Damage']

# %%
hero['Total_defence'] = hero['Phy_Defence'] + hero['Mag_Defence']

# %%
hero['Win_rate'] = hero["Esport_Wins"] / (
    hero["Esport_Wins"] + hero["Esport_Loss"]
)

# %%
hero['Win_rate'].describe()
# Out:
# count    100.000000
# mean       0.477461
# std        0.075023
# min        0.000000
# 25%        0.462852
# 50%        0.497482
# 75%        0.515519
# max        0.578571
# Name: Win_rate, dtype: float64

# %%
hero.duplicated().sum()
# Out:
# np.int64(0)

# %%
hero.head()
# Out:
#      Name Primary_Role      Lane    Hp  Hp_Regen  Mana  Mana_Regen  \
# 0   Aamon     Assassin   Jungler  2614       8.0   455          21
# 1    Akai         Tank    Roamer  2769       8.4   422          12
# 2  Aldous      Fighter  EXP Lane  2718       9.8   405          18
# 3   Alice         Mage  EXP Lane  2573       7.2   493          18
# 4   Alpha      Fighter  EXP Lane  2646       7.8   453          31
#
#    Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  \
# 0         115           0           19           15        250           43
# 1         115           0           24           15        260          540
# 2         129           0           21           15        260           95
# 3         114           0           21           15        240          364
# 4         121           0           25           15        260           24
#
#    Esport_Loss  Total_damage  Total_defence  Win_rate
# ...

# %%
hero['Overall_score'] = (hero['Total_damage'] + hero['Total_defence'] + hero['Mov_Speed'])

# %%
hero.head()
# Out:
#      Name Primary_Role      Lane    Hp  Hp_Regen  Mana  Mana_Regen  \
# 0   Aamon     Assassin   Jungler  2614       8.0   455          21
# 1    Akai         Tank    Roamer  2769       8.4   422          12
# 2  Aldous      Fighter  EXP Lane  2718       9.8   405          18
# 3   Alice         Mage  EXP Lane  2573       7.2   493          18
# 4   Alpha      Fighter  EXP Lane  2646       7.8   453          31
#
#    Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  \
# 0         115           0           19           15        250           43
# 1         115           0           24           15        260          540
# 2         129           0           21           15        260           95
# 3         114           0           21           15        240          364
# 4         121           0           25           15        260           24
#
#    Esport_Loss  Total_damage  Total_defence  Win_rate  Overall_score
# ...

# %%
plt.figure()
plt.hist(hero["Win_rate"], bins=10)
plt.xlabel("Win Rate")
plt.ylabel("Number of Heroes")
plt.title("Distribution of Hero Win Rate")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x="Primary_Role",y="Win_rate",data=hero)
plt.xlabel("Primary Role")
plt.ylabel("Win Rate")
plt.title("Win Rate Distribution by Hero Role")
plt.tight_layout()
plt.show()

# %%
plt.figure()
plt.scatter(hero["Overall_score"], hero["Win_rate"])
plt.xlabel("Overall Score")
plt.ylabel("Win Rate")
plt.title("Overall Score vs Win Rate")
plt.show()

# %%
corr = hero[["Win_rate", "Total_damage", "Total_defence", "Mov_Speed"]].corr()

# %%
plt.figure()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
X = hero[['Overall_score']]
y = hero['Win_rate']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=12)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import accuracy_score, f1_score, mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import ConfusionMatrixDisplay as cmd

# %%
y_pred = model.predict(X_test)

# %%
y_test_cls = (y_test >= 0.5).astype(int)
y_pred_cls = (y_pred >= 0.5).astype(int)

# %%
accuracy = accuracy_score(y_test_cls, y_pred_cls)
f1 = f1_score(y_test_cls, y_pred_cls)

print("Accuracy Score:", accuracy)
print("F1 Score:", f1)
# Out:
# Accuracy Score: 0.6
# F1 Score: 0.0

# %%
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred) 

print("MAE:", mae)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# MAE: 0.04624414232006068
# RMSE: 0.07142764009669994
# R2: -0.03492917418200525

# %%
cmd.from_predictions(y_test_cls,y_pred_cls,display_labels=['Defeat','Victory'])
plt.show()

# %%
import joblib
joblib.dump(model, "draft.joblib")
print("Model saved as draft.joblib")
